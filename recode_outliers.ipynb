# %% [markdown]
# ### In this file we deal with the outliers per dataset

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import skew
from scipy.stats.mstats import winsorize

# %%
os.getcwd()
os.chdir("C:\\Users\\Jacco Bruin .LAPTOP-ACFSBHIL\\THESIS")
data = pd.read_csv('6_year_dataset(1).csv')             # change here the dataset: 6_year_dataset, 3_year_dataset, or 1_year_dataset
data = data.set_index("Ticker_x")
data = data.iloc[:,1:]
data = data.iloc[:,1:]   # if there is index column delete this one first 
data.head()
# Out:
#           year        EBITDA    Total Debt  Free Cash Flow  \
# Ticker_x
# AAL       2010  1.275000e+09  1.113600e+10   -3.780000e+08
# AAL       2011  4.900000e+07  8.220000e+09   -1.067000e+09
# AAL       2012  1.163000e+09  8.535000e+09   -1.039000e+09
# AAL       2013  2.419000e+09  1.679900e+10   -1.297000e+09
# AAL       2014  5.762000e+09  1.772000e+10   -5.650000e+08
#
#           Gross Profit Margin  Operating Margin  Net Profit Margin  \
# Ticker_x
# AAL                    0.2303            0.0139            -0.0212
# AAL                    0.1824           -0.0432            -0.0825
# AAL                    0.2056            0.0060            -0.0755
# AAL                    0.2594            0.0523            -0.0686
# AAL                    0.2815            0.0996             0.0676
#
#           Return on Equity  Return on Assets  Free Cash Flow to Net Income  \
# Ticker_x
# AAL                 0.1194           -0.0188                        0.8026
# ...

# %%
#plots all the features that have a high skewnesss

outliers = []
for i in data.columns:
    if skew(data[i]) > 3 or skew(data[i] < -3):
        plt.hist(data[i], bins = 20)
        plt.title(i)
        plt.show()
        print(skew(data[i]))
        outliers.append(i)
# Out:
# 5.828726500422347
# 3.9256202346413733
# 3.0799839123329615
# -13.32379802049381
# -12.995783671261234
# -17.96155542788353
# 37.693019638904076
# 3.3284598742737908
# 21.663865848811184
# 3.9659095754319584
# 16.89475557357112
# 28.61532596207848
# 18.490000152673364
# 19.69166444303093
# -9.601770380228198
# -0.979510283115338
# 16.080423774750226
# 12.666150571786552
# 12.277809187126481

# %%
for i in outliers:
    data[i] = winsorize(data[i], limits=(0.05, 0.05))

# %%
for i in data.columns:
    plt.hist(data[i], bins = 20)
    plt.title(i)
    plt.show()
    print(skew(data[i]))
# Out:
# 0.0
# 0.0
# 1.5911485030505312
# 2.003110751545811
# 1.3073160031560205
# 0.4735889209696255
# 0.4846314489742008
# 0.05890160639843549
# -0.5123644069764927
# -0.3454256450125723
# -0.3782427853472814
# 0.9404119845990095
# 1.829830995844162
# 0.48655751431434235
# 0.49922423804493077
# 0.5140796768237043
# 1.5394148410755104
# 0.96972907515006
# 0.6731332306661899
# 0.15074019788753226
# -0.36346301809891646
# 0.11032199464874722
# 1.1495935156914188
# -0.2332962004345791
# -0.979510283115338
# -0.08229392254743566
# 0.3835501610309631
# -0.2429448992694867
# -1.1346347593986872
# 0.0
# 1.1702683884983338
# 1.3867203670853112
# 0.86912484183376

# %%
data.to_csv("6_year_dataset(4)(without_outliers).csv")   # change this per dataset analysed

# %% [markdown]
# ### The result is the final dataset for: 6_year_dataset, 3_year_dataset, and 1_year_dataset
